# %%
from datetime import date
atual=date.today().year
nasc=int(input('Digite o ano do seu  nascimento'))
idade=atual-nasc
print('Quem nasceu em {} tem {} anos em {}'.format(nasc,idade,atual))
if(idade==18):
  print('Faça o seu alistamento imediatamente')
elif idade<18:
    resto=18-idade
    print('Ainda faltam tantos {} para seu alistamento'.format(resto))
elif idade>18:
      resto1=18-idade
      print('Voce deveria ter se alistado há {} anos'.format(resto1))
# Out:
# Digite o ano do seu  nascimento2000
# Quem nasceu em 2000 tem 22 anos em 2022
# Voce deveria ter se alistado há -4
