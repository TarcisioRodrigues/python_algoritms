# %%
import random 
n1=str(input('Digite o nome do  aluno:f'))
n2=str(input('Digite o nome do  aluno:'))
n3=str(input('Digite o nome do  aluno:'))
n4=str(input('Digite o nome do  aluno:'))
lista=[n1,n2,n3,n4]

sorteio=random.choice(lista)

print('Aluno escolhido é:',sorteio)
# Out:
# Digite o nome do  aluno:batman
# Digite o nome do  aluno:pacificador
# Digite o nome do  aluno:wolverine
# Digite o nome do  aluno:flash
# Aluno escolhido é: pacificador
