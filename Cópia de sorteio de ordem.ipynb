# %%
import random 
n1=str(input('Digite o nome do  aluno:'))
n2=str(input('Digite o nome do  aluno:'))
n3=str(input('Digite o nome do  aluno:'))
n4=str(input('Digite o nome do  aluno:'))
lista=[n1,n2,n3,n4]

random.shuffle(lista)

print(lista)
# Out:
# Digite o nome do  aluno:ana
# Digite o nome do  aluno:paulo
# Digite o nome do  aluno:jose
# Digite o nome do  aluno:esla
# ['paulo', 'jose', 'ana', 'esla']
