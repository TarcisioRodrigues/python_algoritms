# %%
numero=int(input('Digite um numero para ver a sua tabuada:'))

resultado1=numero*1
resultado2=numero*2
resultado3=numero*3
resultado4=numero*4
resultado5=numero*5
resultado6=numero*6
resultado7=numero*7
resultado8=numero*8
resultado9=numero*9
resultado10=numero*10

print(numero,'X 1:',resultado1)
print(numero,'X 2:',resultado2)
print(numero,'X 3:',resultado3)
print(numero,'X 4:',resultado4)
print(numero,'X 5:',resultado5)
print(numero,'X 6:',resultado6)
print(numero,'X 7:',resultado7)
print(numero,'X 8:',resultado8)
print(numero,'X 9:',resultado9)
print(numero,'X 10:',resultado10)
# Out:
# Digite um numero para ver a sua tabuada:5
# 5 X 1: 5
# 5 X 2: 10
# 5 X 3: 15
# 5 X 4: 20
# 5 X 5: 25
# 5 X 6: 30
# 5 X 7: 35
# 5 X 8: 40
# 5 X 9: 45
# 5 X 10: 50
