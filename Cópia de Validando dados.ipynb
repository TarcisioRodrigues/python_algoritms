# %%
sexo=str(input('Digite M para masculino ou F para Feminino:')).strip().upper()[0]

while sexo not in 'MmFf' :
  sexo=str(input('Por favor digite os dados corretamente!:')).strip().upper()[0]

  print('Sexo {} registrado com sucesso'.format(sexo))
# Out:
# Digite M para masculino ou F para Feminino:sdad
# Por favor digite os dados corretamente!:dasd
# Sexo D registrado com sucesso
# Por favor digite os dados corretamente!:j
# Sexo J registrado com sucesso
# Por favor digite os dados corretamente!:j
# Sexo J registrado com sucesso
# Por favor digite os dados corretamente!:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-a7d7f6201b88> in <module>()
#       2
#       3 while sexo not in 'MmFf' :
# ----> 4   sexo=str(input('Por favor digite os dados corretamente!:')).strip().upper()[0]
#       5
#       6   print('Sexo {} registrado com sucesso'.format(sexo))
#
# IndexError: string index out of range
